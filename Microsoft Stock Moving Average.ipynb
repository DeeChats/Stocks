# %%
#Importing Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import statsmodels.api as sm
from statsmodels.tsa.stattools import adfuller

# %%
#Importing Dataset
data=pd.read_csv("C:/Users/deeks/Downloads/Microsoft_Stock.csv")
data
# Out:
#                     Date    Open    High     Low   Close    Volume
# 0      4/1/2015 16:00:00   40.60   40.76   40.31   40.72  36865322
# 1      4/2/2015 16:00:00   40.66   40.74   40.12   40.29  37487476
# 2      4/6/2015 16:00:00   40.34   41.78   40.18   41.55  39223692
# 3      4/7/2015 16:00:00   41.61   41.91   41.31   41.53  28809375
# 4      4/8/2015 16:00:00   41.48   41.69   41.04   41.42  24753438
# ...                  ...     ...     ...     ...     ...       ...
# 1506  3/25/2021 16:00:00  235.30  236.94  231.57  232.34  34061853
# 1507  3/26/2021 16:00:00  231.55  236.71  231.55  236.48  25479853
# 1508  3/29/2021 16:00:00  236.59  236.80  231.88  235.24  25227455
# 1509  3/30/2021 16:00:00  233.53  233.85  231.10  231.85  24792012
# 1510  3/31/2021 16:00:00  232.91  239.10  232.39  235.77  43623471
#
# [1511 rows x 6 columns]

# %%
#3 yearly Moving Average
data['SMA_3']= data['Close'].rolling(window=10).mean()
print(data['SMA_3'].tail(30))
# Out:
# 1481    243.444
# 1482    243.340
# 1483    242.571
# 1484    241.651
# 1485    240.729
# 1486    239.346
# 1487    238.135
# 1488    237.330
# 1489    236.347
# 1490    234.683
# 1491    232.977
# 1492    232.040
# 1493    231.328
# 1494    231.379
# 1495    231.166
# 1496    231.980
# 1497    232.317
# 1498    232.104
# 1499    232.488
# 1500    233.436
# 1501    233.835
# 1502    233.710
# 1503    234.570
# 1504    234.950
# 1505    235.254
# 1506    234.775
# 1507    234.848
# 1508    234.891
# 1509    234.305
# 1510    234.178
# Name: SMA_3, dtype: float64

# %%
#line plot
data['Close'].plot(color='blue',linewidth=3,figsize=(12,6))
data['SMA_3'].plot(color='yellow',linewidth=3,figsize=(12,6))
#title and labels
plt.title('The Microsoft Closing Stock Price',fontsize=20)
plt.xlabel('Date',fontsize=16)
plt.ylabel('Closing Stock Price',fontsize=16)
# Out:
# Text(0, 0.5, 'Closing Stock Price')

# %%
#5 yearly Moving Average
data['SMA_5']= data['Close'].rolling(window=10).mean()
print(data['SMA_5'].tail(30))
# Out:
# 1481    243.444
# 1482    243.340
# 1483    242.571
# 1484    241.651
# 1485    240.729
# 1486    239.346
# 1487    238.135
# 1488    237.330
# 1489    236.347
# 1490    234.683
# 1491    232.977
# 1492    232.040
# 1493    231.328
# 1494    231.379
# 1495    231.166
# 1496    231.980
# 1497    232.317
# 1498    232.104
# 1499    232.488
# 1500    233.436
# 1501    233.835
# 1502    233.710
# 1503    234.570
# 1504    234.950
# 1505    235.254
# 1506    234.775
# 1507    234.848
# 1508    234.891
# 1509    234.305
# 1510    234.178
# Name: SMA_5, dtype: float64

# %%
#line plot
data['Close'].plot(color='red',linewidth=3,figsize=(12,6))
data['SMA_5'].plot(color='orange',linewidth=3,figsize=(12,6))
#title and labels
plt.title('The Microsoft Closing Stock Price',fontsize=20)
plt.xlabel('Date',fontsize=16)
plt.ylabel('Closing Stock Price',fontsize=16)
# Out:
# Text(0, 0.5, 'Closing Stock Price')

# %%
#7 yearly Moving Average
data['SMA_7']= data['Close'].rolling(window=10).mean()
print(data['SMA_7'].tail(30))
# Out:
# 1481    243.444
# 1482    243.340
# 1483    242.571
# 1484    241.651
# 1485    240.729
# 1486    239.346
# 1487    238.135
# 1488    237.330
# 1489    236.347
# 1490    234.683
# 1491    232.977
# 1492    232.040
# 1493    231.328
# 1494    231.379
# 1495    231.166
# 1496    231.980
# 1497    232.317
# 1498    232.104
# 1499    232.488
# 1500    233.436
# 1501    233.835
# 1502    233.710
# 1503    234.570
# 1504    234.950
# 1505    235.254
# 1506    234.775
# 1507    234.848
# 1508    234.891
# 1509    234.305
# 1510    234.178
# Name: SMA_7, dtype: float64

# %%
#line plot
data['Close'].plot(color='purple',linewidth=3,figsize=(12,6))
data['SMA_7'].plot(color='pink',linewidth=3,figsize=(12,6))
#title and labels
plt.title('The Microsoft Closing Stock Price',fontsize=20)
plt.xlabel('Date',fontsize=16)
plt.ylabel('Closing Stock Price',fontsize=16)
# Out:
# Text(0, 0.5, 'Closing Stock Price')

# %%
#10 yearly Moving Average
data['SMA_10']= data['Close'].rolling(window=10).mean()
print(data['SMA_10'].tail(30))
# Out:
# 1481    243.444
# 1482    243.340
# 1483    242.571
# 1484    241.651
# 1485    240.729
# 1486    239.346
# 1487    238.135
# 1488    237.330
# 1489    236.347
# 1490    234.683
# 1491    232.977
# 1492    232.040
# 1493    231.328
# 1494    231.379
# 1495    231.166
# 1496    231.980
# 1497    232.317
# 1498    232.104
# 1499    232.488
# 1500    233.436
# 1501    233.835
# 1502    233.710
# 1503    234.570
# 1504    234.950
# 1505    235.254
# 1506    234.775
# 1507    234.848
# 1508    234.891
# 1509    234.305
# 1510    234.178
# Name: SMA_10, dtype: float64

# %%
#line plot
data['Close'].plot(color='green',linewidth=3,figsize=(12,6))
data['SMA_10'].plot(color='grey',linewidth=3,figsize=(12,6))
#title and labels
plt.title('The Microsoft Closing Stock Price',fontsize=20)
plt.xlabel('Date',fontsize=16)
plt.ylabel('Closing Stock Price',fontsize=16)
# Out:
# Text(0, 0.5, 'Closing Stock Price')
